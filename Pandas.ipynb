# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
#question 6.2
subjects = {"sub1": "Python", "sub2": "Maths", "sub3": "LADE"}
myvar = pd.Series(subjects)
print(myvar)
# Out:
# sub1    Python
# sub2     Maths
# sub3      LADE
# dtype: object

# %%
subjects = {"sub1": ["Python","c++"], "sub2":["Maths","algebra"], "sub3":["LADE","stats"]}
myvar = pd.DataFrame(subjects)
print(myvar)
# Out:
#      sub1     sub2   sub3
# 0  Python    Maths   LADE
# 1     c++  algebra  stats

# %%
#question 6.1
l1=["Python","Maths"]
l2=["s1","s2"]
s1=pd.Series(l1,l2)
s1
# Out:
# s1    Python
# s2     Maths
# dtype: object

# %%
#question 6.3
s1= ['Python','ML','NLP','DL']
s2= ['9','8','7','9']
s3= ['7','8','9','9']
final=[s1,s2,s3]
df=pd.DataFrame(final)
df
# Out:
#         0   1    2   3
# 0  Python  ML  NLP  DL
# 1       9   8    7   9
# 2       7   8    9   9

# %%
df = pd.Series({'s1': ['Python','ML','NLP','DL'],'s2': ['9','8','7','9'],'s3': ['7','8','9','9']})
df
# Out:
#        s1 s2 s3
# 0  Python  9  7
# 1      ML  8  8
# 2     NLP  7  9
# 3      DL  9  9

# %%
#Question :   chagnging  headers
dict = {'s1': 'Name',
        's2': 'marks1',
        's3': 'marks2'}


# call rename () method
df.rename(columns=dict,
          inplace=True)
df
# Out:
#      Name marks1 marks2
# 0  Python      9      7
# 1      ML      8      8
# 2     NLP      7      9
# 3      DL      9      9

# %%
#question 6.4
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_is_numpy_dev',
#  '_libs',
#  '_testing',
#  '_typing',
#  '_version',
#  'annotations',
#  'api',
#  'array',
#  'arrays',
#  'bdate_range',
#  'compat',
#  'concat',
#  'core',
#  'crosstab',
#  'cut',
#  'date_range',
#  'describe_option',
#  'errors',
#  'eval',
#  'factorize',
#  'from_dummies',
#  'get_dummies',
#  'get_option',
#  'infer_freq',
#  'interval_range',
#  'io',
#  'isna',
#  'isnull',
#  'json_normalize',
#  'lreshape',
#  'melt',
#  'merge',
#  'merge_asof',
#  'merge_ordered',
#  'notna',
#  'notnull',
#  'offsets',
#  'option_context',
#  'options',
#  'pandas',
#  'period_range',
#  'pivot',
#  'pivot_table',
#  'plotting',
#  'qcut',
#  'read_clipboard',
#  'read_csv',
#  'read_excel',
#  'read_feather',
#  'read_fwf',
#  'read_gbq',
#  'read_hdf',
#  'read_html',
#  'read_json',
#  'read_orc',
#  'read_parquet',
#  'read_pickle',
#  'read_sas',
#  'read_spss',
#  'read_sql',
#  'read_sql_query',
#  'read_sql_table',
#  'read_stata',
#  'read_table',
#  'read_xml',
#  'reset_option',
#  'set_eng_float_format',
#  'set_option',
#  'show_versions',
#  'test',
#  'testing',
#  'timedelta_range',
#  'to_datetime',
#  'to_numeric',
#  'to_pickle',
#  'to_timedelta',
#  'tseries',
#  'unique',
#  'util',
#  'value_counts',
#  'wide_to_long']

# %%
#Create a Series using only data from "day1" and "day2":

calories = {"day1": 420, "day2": 380, "day3": 390}
myvar = pd.Series(calories, index = ["day1", "day2"])
print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %%
#dir(pd)

# %%
#series
lst = [7,1,2,3,5] # we can have tuple too
s = pd.Series(lst)
s
# Out:
# 0    7
# 1    1
# 2    2
# 3    3
# 4    5
# dtype: int64

# %%
tuple = (7,1,2,3,5)
list = ["C","C++","Java","R","Python"]
s1 = pd.Series(tuple,index=list)
s1
# Out:
# C         7
# C++       1
# Java      2
# R         3
# Python    5
# dtype: int64

# %%
#### Series
tuple = ("E","E","E","D","C")
list = ["C","C++","Java","R","Python"]
s2 = pd.Series(tuple,index=list)
s2
# Out:
# C         E
# C++       E
# Java      E
# R         D
# Python    C
# dtype: object

# %%
import pandas as pd
tuple = ("E","E","E","D","C")
list = ["C","C++","Java","R","Python"]
s2 = pd.Series(tuple,list)
s2
# Out:
# C         E
# C++       E
# Java      E
# R         D
# Python    C
# dtype: object

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}
myvar = pd.DataFrame(data)
print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
#Question 6.4
df = pd.read_csv("/content/Iris.csv")
df.columns=["srno","Tanuj","Tanvi","Khushi","Soham","Hari"]
df
# Out:
#      srno  Tanuj  Tanvi  Khushi  Soham            Hari
# 0       1    5.1    3.5     1.4    0.2     Iris-setosa
# 1       2    4.9    3.0     1.4    0.2     Iris-setosa
# 2       3    4.7    3.2     1.3    0.2     Iris-setosa
# 3       4    4.6    3.1     1.5    0.2     Iris-setosa
# 4       5    5.0    3.6     1.4    0.2     Iris-setosa
# ..    ...    ...    ...     ...    ...             ...
# 145   146    6.7    3.0     5.2    2.3  Iris-virginica
# 146   147    6.3    2.5     5.0    1.9  Iris-virginica
# 147   148    6.5    3.0     5.2    2.0  Iris-virginica
# 148   149    6.2    3.4     5.4    2.3  Iris-virginica
# 149   150    5.9    3.0     5.1    1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
#que 6.6
#df.iloc[0:2,0:2]
#df.tail(5)

#Que 6.7
#df.dtypes
df.describe()
# Out:
#              srno       Tanuj       Tanvi      Khushi       Soham
# count  150.000000  150.000000  150.000000  150.000000  150.000000
# mean    75.500000    5.843333    3.054000    3.758667    1.198667
# std     43.445368    0.828066    0.433594    1.764420    0.763161
# min      1.000000    4.300000    2.000000    1.000000    0.100000
# 25%     38.250000    5.100000    2.800000    1.600000    0.300000
# 50%     75.500000    5.800000    3.000000    4.350000    1.300000
# 75%    112.750000    6.400000    3.300000    5.100000    1.800000
# max    150.000000    7.900000    4.400000    6.900000    2.500000

# %%
df['Marks'] = s1
df["Grade"] = s2
df
# Out:
#         Marks Grade
# C           7     E
# C++         1     E
# Java        2     E
# R           3     D
# Python      5     C

# %%
# adding column to DF
df["School Name"] = "STME"
df
# Out:
#         Marks Grade School Name
# C           7     E        STME
# C++         1     E        STME
# Java        2     E        STME
# R           3     D        STME
# Python      5     C        STME

# %%
df["Location"] = "Navi Mumbai"
df
# Out:
#         Marks Grade School Name     Location
# C           7     E        STME  Navi Mumbai
# C++         1     E        STME  Navi Mumbai
# Java        2     E        STME  Navi Mumbai
# R           3     D        STME  Navi Mumbai
# Python      5     C        STME  Navi Mumbai

# %%
#Dropping.... Column
df.drop(['Location'],axis=1,inplace=True)   #### axis =1 --we are deleting columns
df
# Out:
#         Marks Grade School Name
# C           7     E        STME
# C++         1     E        STME
# Java        2     E        STME
# R           3     D        STME
# Python      5     C        STME

# %%
df[["Marks","Grade"]]
# Out:
#         Marks Grade
# C           7     E
# C++         1     E
# Java        2     E
# R           3     D
# Python      5     C

# %%
#dropping row
df.drop(['Python'],axis=0,inplace=True)   #### axis =0 --we are deleting row

# %%
df
# Out:
#       Marks Grade School Name     Location
# C         7     E        STME  Navi Mumbai
# C++       1     E        STME  Navi Mumbai
# Java      2     E        STME  Navi Mumbai
# R         3     D        STME  Navi Mumbai

# %%
df.iloc[:]
# Out:
#       Marks Grade School Name     Location
# C         7     E        STME  Navi Mumbai
# C++       1     E        STME  Navi Mumbai
# Java      2     E        STME  Navi Mumbai
# R         3     D        STME  Navi Mumbai

# %%
df.iloc[1:3]
# Out:
#       Marks Grade School Name     Location
# C++       1     E        STME  Navi Mumbai
# Java      2     E        STME  Navi Mumbai

# %%
df.loc['C++']
# Out:
# Marks                    1
# Grade                    E
# School Name           STME
# Location       Navi Mumbai
# Name: C++, dtype: object

# %%
df.loc['Java']
# Out:
# Marks               2
# Grade               E
# School Name    MPSTME
# Name: Java, dtype: object

# %%
df = df.reset_index()  # to set/reset index
df.head(10)
# Out:
#   index  Marks Grade School Name     Location
# 0     C      7     E        STME  Navi Mumbai
# 1   C++      1     E        STME  Navi Mumbai
# 2  Java      2     E        STME  Navi Mumbai
# 3     R      3     D        STME  Navi Mumbai

# %%
# Index labels
# Each item in a Series object has a unique identifier called the index label.
# By default, it is simply the rank of the item in the Series (starting at 0)
s2 = pd.Series([68, 83, 112, 68])
print(s2)
# Out:
# 0     68
# 1     83
# 2    112
# 3     68
# dtype: int64

# %%
# Set the index labels manually
s2 = pd.Series([68, 83, 112, 68], index=["Stone", "Gold", "Tom", "Sam"])
print(s2)
# Out:
# Stone     68
# Gold      83
# Tom      112
# Sam       68
# dtype: int64

# %%
# Access the items in series
# We can either access the items by specifying integer location or label
print(s2[2])
print(s2["Tom"])
# Out:
# 112
# 112

# %%
# It is recommended to always use the loc attribute when accessing by label,
# and the iloc attribute when accessing by integer location
print(s2.loc["Tom"])
print(s2.iloc[2])
# Out:
# 112
# 112

# %%
# Init from dict
# We can create Series object from Python dict
weights = {"Stone": 68, "Gold": 83, "Tom": 86, "Sam": 68, 'Deck':32}
s3 = pd.Series(weights)
print(s3)
# Out:
# Stone    68
# Gold     83
# Tom      86
# Sam      68
# Deck     32
# dtype: int64

# %%
#question 6.2
# Init from dict
weights = {"Stone":['68'], "Gold":['83'], "Tom": ['86'], "Sam": ['68'], 'Deck':['32']}
s3 = pd.DataFrame(weights)
print(s3)
# Out:
#   Stone Gold Tom Sam Deck
# 0    68   83  86  68   32

# %%
# We can control which elements you want to include in the Series and
# in what order by explicitly specifying the desired index
s4 = pd.Series(weights, index = ["Deck", "Sam"])
print(s4)
# Out:
# Deck    32
# Sam     68
# dtype: int64

# %%
# Series name
# Here the series name is weights

s6 = pd.Series([83, 68], index=["bob", "alice"], name="weights")
print(s6)
# Out:
# bob      83
# alice    68
# Name: weights, dtype: int64

# %%
df = pd.read_csv("D:\Python Programming\PP I\iris.csv")
# use read_excel() to read excel files
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df = pd.read_csv("D:\Python Programming\PP I\iris.csv", header=None)
df # Header will not be set
# Out:
#        0              1             2              3             4  \
# 0     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 1      1            5.1           3.5            1.4           0.2
# 2      2            4.9           3.0            1.4           0.2
# 3      3            4.7           3.2            1.3           0.2
# 4      4            4.6           3.1            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 146  146            6.7           3.0            5.2           2.3
# 147  147            6.3           2.5            5.0           1.9
# 148  148            6.5           3.0            5.2           2.0
# 149  149            6.2           3.4            5.4           2.3
# 150  150            5.9           3.0            5.1           1.8
#
#                   5
# 0           Species
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
# 150  Iris-virginica
#
# [151 rows x 6 columns]

# %%
#df[-1:-5:-1]
#df.head(5)
df.tail(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
import pandas as pd
#question 6.5
names=['x1','x2','x3','x4','Y']
df1 = pd.read_csv("/content/Iris.csv", names=names) #Header will be seta
df1
# Out:
#                 x1            x2             x3            x4               Y
# Id   SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [151 rows x 5 columns]

# %%
# To add header manually.... second way...
# create headers list
df.columns = ["x1","x2","x3","x4","y","W"]
df
#df.head(10)
# Out:
#       x1   x2   x3   x4    y               W
# 0      1  5.1  3.5  1.4  0.2     Iris-setosa
# 1      2  4.9  3.0  1.4  0.2     Iris-setosa
# 2      3  4.7  3.2  1.3  0.2     Iris-setosa
# 3      4  4.6  3.1  1.5  0.2     Iris-setosa
# 4      5  5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...  ...             ...
# 145  146  6.7  3.0  5.2  2.3  Iris-virginica
# 146  147  6.3  2.5  5.0  1.9  Iris-virginica
# 147  148  6.5  3.0  5.2  2.0  Iris-virginica
# 148  149  6.2  3.4  5.4  2.3  Iris-virginica
# 149  150  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
# show the first 5 rows using dataframe.head() method
df.head(-5)
# Out:
#       x1   x2   x3   x4               Y
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 140  6.7  3.1  5.6  2.4  Iris-virginica
# 141  6.9  3.1  5.1  2.3  Iris-virginica
# 142  5.8  2.7  5.1  1.9  Iris-virginica
# 143  6.8  3.2  5.9  2.3  Iris-virginica
# 144  6.7  3.3  5.7  2.5  Iris-virginica
#
# [145 rows x 5 columns]

# %%
df.tail(10)# shows the last 10 rows
# Out:
#       x1   x2   x3   x4               Y
# 140  6.7  3.1  5.6  2.4  Iris-virginica
# 141  6.9  3.1  5.1  2.3  Iris-virginica
# 142  5.8  2.7  5.1  1.9  Iris-virginica
# 143  6.8  3.2  5.9  2.3  Iris-virginica
# 144  6.7  3.3  5.7  2.5  Iris-virginica
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica

# %%
# To save dataset
df.to_csv("ddd.csv", index=False)

# %%
# to know datatype
print(df.dtypes)
# Out:
# x1    float64
# x2    float64
# x3    float64
# x4    float64
# Y      object
# dtype: object

# %%
# describe statistical summary of each column, such as count, column mean value, column standard deviation, etc.
df.describe()   # covers numeric coluns
# Out:
#                x1          x2          x3          x4
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
# to descibe object columns too
df.describe(include='all')
# Out:
#                 x1          x2          x3          x4            Y
# count   150.000000  150.000000  150.000000  150.000000          150
# unique         NaN         NaN         NaN         NaN            3
# top            NaN         NaN         NaN         NaN  Iris-setosa
# freq           NaN         NaN         NaN         NaN           50
# mean      5.843333    3.054000    3.758667    1.198667          NaN
# std       0.828066    0.433594    1.764420    0.763161          NaN
# min       4.300000    2.000000    1.000000    0.100000          NaN
# 25%       5.100000    2.800000    1.600000    0.300000          NaN
# 50%       5.800000    3.000000    4.350000    1.300000          NaN
# 75%       6.400000    3.300000    5.100000    1.800000          NaN
# max       7.900000    4.400000    6.900000    2.500000          NaN

# %%
# describe selected columns
#df[[' ', ' ']].describe()

# %%
#que 6.8
# Another methhod to check summary is
#df.info()
#df['srno'].astype(str)
#df.drop(columns='srno')
df.drop(1,axis=0,inplace=True)

# %%
# to drop Column
data.drop(1,axis=0,inplace=True)
data.head()

# %%
df.to_csv("nm.csv")

# %%
# to rename column
data.rename(columns={"Country/Region":"Country"},inplace=True)

# %%
# Save to CSV, HTML and JSON
my_df.to_csv("my_df.csv")
my_df.to_html("my_df.html")
my_df.to_json("my_df.json")

# %%
#question no 6.9
df.to_csv("my_df.csv")

# %%
#Plotting Graphs

# %%
import pandas as pd
test1 = (2,5,7,9,10)
list = ["C","C++","Java","R","Python"]
s1 = pd.Series(test1,index=list)
s1
# Out:
# C          2
# C++        5
# Java       7
# R          9
# Python    10
# dtype: int64

# %%
test2 = (3,6,7,8,9)
list = ["C","C++","Java","R","Python"]
s2 = pd.Series(test2,index=list)
s2
# Out:
# C         3
# C++       6
# Java      7
# R         8
# Python    9
# dtype: int64

# %%
df = pd.DataFrame()
df['Test1'] = s1
df["Test2"] = s2
df
# Out:
#         Test1  Test2
# C           2      3
# C++         5      6
# Java        7      7
# R           9      8
# Python     10      9

# %%
df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
df['Test2'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df
# Out:
#         Test1  Test2
# C           2      3
# C++         5      6
# Java        7      7
# R           9      8
# Python     10      9

# %%
#Stacked Area Graphs
import pandas as pd
df = pd.read_csv("areaplt.csv")
df.head()
# Out:
#    year  basic  saving  money_mkt  credit
# 0  2012   3000    6000        500    1000
# 1  2013   1200   12000        700    2000
# 2  2014   2500   11000       1200    1000
# 3  2015   1800   11500       1700    1000
# 4  2016   1200   14000       2000    2000

# %%
df.drop(['year'],axis=1,inplace=True)
df.plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
#Box Plot...
df.head(8)
# Out:
#    basic  saving  money_mkt  credit
# 0   3000    6000        500    1000
# 1   1200   12000        700    2000
# 2   2500   11000       1200    1000
# 3   1800   11500       1700    1000
# 4   1200   14000       2000    2000
# 5   2300   13500       1200    1000
# 6   1600   14000       1600    1500
# 7   2000   15000       1456    3000

# %%
# Box Plot
df['saving'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
# Scatter
df.plot(kind='scatter',x='basic',y='credit')
# Out:
# <AxesSubplot:xlabel='basic', ylabel='credit'>

# %%
# Scatter Plot...
d={'Nm':['DJ', 'DK', 'RK','SB', 'VS', 'PJ'], 'Ag':[20, 18, 27, 50, 12, 15]}

# Load data into DataFrame
df = pd.DataFrame(data = d);

# Draw a scatter plot
df.plot.scatter(x = 'Nm', y = 'Ag', s = 100);
