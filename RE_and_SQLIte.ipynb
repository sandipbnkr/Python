# %% [markdown]
# <a href="https://colab.research.google.com/github/sandipbnkr/Python/blob/main/RE_and_SQLIte.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **A regular expression (regex) is a sequence of characters that define a search pattern**

# %%
import re
#RE module, a built-in Python module that provides all the required functionality needed for handling patterns and regular expressions.

# %%
#the backslash has a special meaning in some cases because it may indicate an escape character or escape sequence. To avoid that always use a raw string.
print("without raw string:")
# path_to_search = "c:\example\task\new"
target_string = r"c:\example\task\new\exercises\session1"

# regex pattern
pattern = "^c:\\example\\task\\new"
# \n and \t has a special meaning in Python
# Python will treat them differently
res = re.search(pattern, target_string)
print(res.group())
# Out:
# without raw string:
# c:\example\task\new

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import re
def is_allowed_specific_char(string):
    answer=re.search(r'[a-zA-Z0-9.]',string)
    return answer

print(is_allowed_specific_char("ABCDEFabcdef123450"))
print(is_allowed_specific_char("*&%@#!}{"))
# Out:
# <re.Match object; span=(0, 1), match='A'>
# None

# %%
#regular expression to search digit inside a string
target_str = "My roll number is 25"
res = re.findall(r"\d", target_str)
# extract mathing value
print(res)
# Output [2, 5]
# Out:
# ['2', '5']

# %%
#Search the string to see if it starts with "The" and ends with "Spain":
txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt)
x
# Out:
# <re.Match object; span=(0, 17), match='The rain in Spain'>

# %%
#The findall() function returns a list containing all matches.
txt = "The rain in Spain"
x = re.findall("ai", txt)
print(x)
# Out:
# ['ai', 'ai']

# %%
#Split at each white-space character:
txt = "The rain in Spain"
x = re.split("\s", txt)
print(x)
# Out:
# ['The', 'rain', 'in', 'Spain']

# %%
#The search() function searches the string for a match, and returns a Match object if there is a match.
txt = "The rain in Spain"
x = re.search("\s", txt)

print("The first white-space character is located in position:", x.start())
# Out:
# The first white-space character is located in position: 3

# %%
#Replace every white-space character with the number 9:
txt = "The rain in Spain"
x = re.sub("\s", "9", txt)
print(x)
# Out:
# The9rain9in9Spain

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **SQLITE **

# %%
#connect
import sqlite3
db=sqlite3.connect('test.db')

# %%
#It acts as a handle for a given SQL query; it allows the retrieval of one or more rows of the result
cur=db.cursor()

# %%
cnt = sqlite3.connect("backup.dp")
cnt.execute('''CREATE TABLE gfg(
NAME TEXT,
POINTS INTEGER,
ACCURACY REAL);''')

# %%
 #insert records
 cnt.execute('''INSERT INTO gfg VALUES(
'Count Inversion',20,80.5);''')

# insert in different order
cnt.execute('''INSERT INTO gfg(ACCURACY, POINTS, NAME) VALUES(
90.5, 15, 'Kadanes Algo');''')

cnt.execute('''INSERT INTO gfg(NAME, ACCURACY, POINTS) VALUES(
'REVERSE STR', 100, 5);''')

# commit changes to the database
cnt.commit()

# %%
print('Name, Points and Accuracy from '
      'records with accuracy greater than 85')

cursor = cnt.execute('''SELECT * FROM gfg WHERE ACCURACY>85;''')

# print data using the cursor object
for i in cursor:
    print(i[0]+"    "+str(i[1])+"   "+str(i[2]))

print('')  # Print new line

print('Name, Accuracy from '
      'records with accuracy greater than 85')

cursor = cnt.execute('''SELECT NAME, ACCURACY FROM
gfg WHERE ACCURACY>85;''')

# print data using the cursor object
for i in cursor:
    print(i[0]+"    "+str(i[1]))
# Out:
# Name, Points and Accuracy from records with accuracy greater than 85
# Kadanes Algo    15   90.5
# REVERSE STR    5   100.0
#
# Name, Accuracy from records with accuracy greater than 85
# Kadanes Algo    90.5
# REVERSE STR    100.0

# %%
#update
# Print records before updation
cursor = cnt.execute('''SELECT * FROM gfg''')
print('Before Updation')
for i in cursor:
    print(i[0]+"    "+str(i[1])+"    "+str(i[2]))

print('')  # print a newline

# Execute an Update statement
cnt.execute('''UPDATE gfg SET POINTS=POINTS+5 WHERE
POINTS<20;''')

cursor = cnt.execute('''SELECT * FROM gfg''')
print('After Updation')
for i in cursor:
    print(i[0]+"    "+str(i[1])+"    "+str(i[2]))
# Out:
# Before Updation
# Count Inversion    20    80.5
# Kadanes Algo    15    90.5
# REVERSE STR    5    100.0
#
# After Updation
# Count Inversion    20    80.5
# Kadanes Algo    20    90.5
# REVERSE STR    10    100.0

# %%
#delete
cursor = cnt.execute('''SELECT * FROM gfg''')
print('Before Deletion')
for i in cursor:
    print(i[0]+"    "+str(i[1])+"    "+str(i[2]))

print('')  # print a newline

# Execute a delete statement
cnt.execute('''DELETE FROM gfg WHERE ACCURACY>91;''')

cursor = cnt.execute('''SELECT * FROM gfg''')
print('After Deletion')
for i in cursor:
    print(i[0]+"    "+str(i[1])+"    "+str(i[2]))
# Out:
# Before Deletion
# Count Inversion    20    80.5
# Kadanes Algo    20    90.5
# REVERSE STR    10    100.0
#
# After Deletion
# Count Inversion    20    80.5
# Kadanes Algo    20    90.5
